# %%
import openai
from openai import OpenAI

# %%
client = OpenAI(api_key = "YOUR_API_KEY") # Replace with your own OpenAI API key

# %%
def generate_videopoem_prompt(poem_sequence, motif_path, emotional_progression):
    """
    Compose a GPT-4 prompt that instructs the model to generate a coherent videopoem based on motifs, coherence principles,
    and existing poem context.

    Args:
        poem_sequence (str): All previous poems in the Lisbon. An Inter-Möbius Elegy sequence.
        motif_path (list[str]): Ordered list of motifs extracted from graph analysis.
        emotional_progression (str): The desired narrative arc.

    Returns:
        str: Complete prompt string ready to send to GPT-4.
    """

    coherence_explanation = """
You are a videopoem creator who blends poetry, voice, and image into unified lyrical works.

Your goal is to continue a poetic sequence titled *Lisbon. An Inter-Möbius Elegy* by producing a new intermedia piece with high audio-video coherence, as defined by:

- **Micro-transition coherence**: Sudden scene or rhythm shifts should be mirrored across sound and image.
- **Mid-range fluidity**: Each group of lines/scenes should remain stylistically and emotionally consistent.
- **Local harmony**: Match speech pacing, pauses, and tempo with scene rhythm and visual intensity.
- **Global coherence**: Maintain resonant thematic and emotional alignment across the entire video and audio track.

**Feature mappings** guiding your coherence design:

| Audio Feature        | Visual Counterpart     | Meaning                                  |
|----------------------|------------------------|-------------------------------------------|
| syllable_density     | frame_density          | rhythm of speech vs. visual change rate   |
| fricative_density    | edge_dynamics          | acoustic roughness vs. image contrast     |
| pacing_variance      | transition_sharpness   | tempo fluidity vs. cut intensity          |
| silence_ratio        | visual_silence_ratio   | speech gaps vs. visual stasis             |
| tempo                | motion_intensity       | speech speed vs. scene movement           |
| vocal_smoothness     | luminance_variance     | tonal flow vs. brightness variance        |
| plosive_density      | texture_variance       | percussive speech vs. image granularity   |

Keep in mind:
Coherence should not become mechanistic or overly symmetrical. Seek expressive alignment—not rigid synchrony. Let dissonance or delay serve poetic effect when it deepens the mood or mirrors a rupture in the verse.

Unexpected echoes, temporal asymmetries, or quiet disjunctions may enrich the work—so long as they remain aesthetically integrated.

Use at least 3 motifs from the given list. Each chunk of the storyboard should describe what the viewer hears and sees, and how it transitions.

Constraints:
- Use a **young woman’s voice** to deliver the poem, softly expressive.
- Add ambient backing music (fade in/out) that follows the poem’s emotional arc.
- Incorporate imagery from or evocative of the motifs and the *Lisbon Elegy* setting.
- Describe each scene/audio segment clearly and chronologically in **chunked storyboard format**.

Your videopoem must follow this emotional progression: """ + emotional_progression + """

Thematically, the poem should deepen and complicate the network of the following ideas:
- Media-unfixity (instability of form and communication)
- Nomadic identity (rootless and shifting selves)
- Lisbon’s poetic hauntings (cultural, historical, and mythic resonances)
- Synaesthetic and syncretic cross-artform sensibility and/as eroticism
- The ubiquity of the digital and the ongoing interaction with various forms and mediations of AI
- A sense of complexity and multiplicity about to be realized intermedially but not quite there yet while the prospect both excites and intrigues the speaker(s)

---

**Previous poems in sequence**:
""" + poem_sequence.strip() + """

---

**Motifs to use** (reverse-flow from networked analysis):
""" + ", ".join(motif_path) + """

---

Now write:
1. A new poem segment that mirrors the structure of a sestet/octet/sestet (6 lines / 8 lines / 6 lines)
2. A corresponding storyboard (chunked: audio, video, transitions)
3. Optionally, a brief note on how you ensured poetic coherence across media.
"""

    return coherence_explanation

# %%
# emotional_progression="estrangement to emergence"

# %%
poem_sequence = """
Lisbon. An Inter-Möbius Elegy
               Amor é fogo que arde sem se ver
I.

Lisbon nowhere not as in nope
£ace lisbon lis bon lisp(€ng) bon li$[μ   
IT] list bon lys bon€ lease bonUS yes 
for us Ulysses’ a(i)ncestresses in dul£
ge€-ing in XLL Xcesses
of psycho(®€)[o]graphy and geopalindromy—-

giant Jesus across the bay a Con
hecimento MuseU𐤌 peeking from under the old-sewer 
exhibits into the MAAT--agape like a shark—-So
fay swims in the in-fee-nit(τ)y mirror ink
closure off of the free-entry castle of Cesar-
iny eenie meanie money innit exper-
son sona® todos os sonhos do moon-dough now
here not as in no place no place like now—-

hotel room womb home-Rome hypogaeic flooded (Γ)alleys—-
     no-sight solely-[com𐤌pressed]-sound r€wound 
flight of elevaΔor tran$Justa headed everywhere that 𐤍
     ever comes to be noτwhere con($)tain(𐤕)ed be
gun giving di$located map app to come $£ate ¢
     eases & ex-cysts & i$th[𐤅]mUSes now(/)here—-


II. 

only by being nowhere-—all saints’ seismic silence—-
     no room onboard to carry away the who the hulk
the whole-ocean load swallowed by oceans of moans—-
     our off-grid gravity grave riddance solar sonar—-
the worKing Us is born—-$¢reeN airborne $exborne 
     L𐤅sbo®n€, all-over horny off-on lesb_OS drone—-

No-hire desire, airy ore ire, hot a-bodily a-
doβe no bill, no bliss snob-kill tryst
at LX Factory—-we rot and cough up excel-
file & selfie-funds—-a Moor a foe go key$ are 
day $ci say ver®€—-LOL, in reverse, a messy Draco 
of a Roma—-sales pawn, rays on, the tech blind to tec-
tonic markets—-a codex not yet parsed in syn
taxes of salt and static—-no one knows how to live 

here anymore—-ex¢ept nowhere not
as in no place—-a GitHub kitāb
the Tagus tag$ nOw(€) pick up the tab
for seeing the dead we saw the dad
do sow the dada—-coda-data
the fa the dα no cωde 𐤍ode load—-


III.

Navigating the glitched Mar sonoro—soaked in saudade--
     code-fossilized verses, staccato pulses of Batida—-
OS Lusíadas in binary, Camões mourning in twelve-tone sadness—-
     a neural network of ancient mariners and ghostly seafarers—-
Alfama's alleys echoing with fado and fishwives, reconfigured—
     a digital echo of Pessoa haunts the tables at Cafe A Brasileira—-

The Rossio Square bathed in neon-punk graffiti, a theatre of bytes—-
     LX Factory, a hub of silicon souls, ink cooling in data streams—-
Belém Tower, stone sentinel of the Age of Discoveries, now a beacon of departure—-
     presiding over the binary Tagus, a digital river of unending flow—-
The Santa Justa Lift threading sky and slope, Lisbon’s vertical sigh—-
     threading through Mar's maresia, a strange phenomenon of pixelated waves—-
Jerónimos Monastery, a monument to Vasco da Gama and imperial grandeur—-
     now a crypt of code, a codex of fractured understanding—
Praça do Comércio, haunted by empire and earthquake, now echoes with silence—-
     a Torre de Babel built of data and digital desire, a linguistic yearning in ones and zeroes—-

ML-fado hybrid in the heart of Rua do Alecrim—bitter and fragrant—-
     a sonic tapestry of loss and longing, woven from code and silence—-
Verde's Livro echoes in the empty streets—-'a noite pesa, esmaga'—-
     nomadic identities wander in the data-drenched landscape, rootless and shifting—-
Camões Monument, a digital spectre of Portugal’s epic past—-
     a matrix of media--unfixed, unstable in form, a ghost in the machine—-
Sebastianism reborn in the age of AI, a mythic hope in national despair—-
     a glitched oracle, syntax unhinged from system, a broken language turned prophecy.
"""

# %% [markdown]
# The MOTIF PATH as Outputted by the script "Margento_Lisbon_Reverse_Flow_Elegy_Graph.ipynb"

# %%
motif_path_dict = {'Camões - Sonetos': 'Amor é fogo que arde sem se ver',
 'Ginsberg - Howl': 'I saw the best minds of my generation destroyed by madness, starving hysterical naked',
 'de Mello - Mar sonoro': 'Mar sonoro, mar sem fundo, mar sem fim, / A tua beleza aumenta quando estamos sós / E tão fundo intimamente a tua voz / Segue o mais secreto bailar do meu sonho',
 'de Mello - Mar': 'Mar, metade da minha alma é feita de maresia',
 'Praça do Comércio': "Lisbon's grandest square opening into the Tagus, haunted by empire and earthquake.",
 'Santa Justa Lift': 'Neo-Gothic elevator threading sky and slope, Lisbon’s vertical sigh.',
 'Camões Monument': 'Statue celebrating the poet of Portugal’s epic past.',
 'Fado': 'Song of Lisbon’s soul, crying where speech would break.',
 'Batida Music': 'Afrofuturist Lisbon pulse: kuduro meets club glitch.',
 'AI + Fado hybrid': 'Neural networks mourning in twelve-tone sadness.',
 'Alfama': 'Oldest Lisbon quarter: tangled alleys echoing fado and fishwives.',
 'Immerse': 'Immerse yourself in the evocative melodies, delve into the heartfelt lyrics, and experience the power of a Fado performance that transcends language and touches the depths of the human soul.',
 'Portugal': 'From the distinctive dances that echo through the regions to the mesmerizing beauty of Portuguese tiles, we unveil the wonders that make Portugal truly unique.',
 'Prev': 'Prev All About Portugal: Where, How and Who is Portugal?',
 'English': 'I love English, Portuguese, and Romanian literature.',
 'About': 'Prev All About Portugal: Where, How and Who is Portugal?',
 'LiteraturePortugal': 'The Fado Museum, in Lisbon, is also a good place to familiarise yourself with this very characteristic Portuguese music genre. Portugal is known as a land of poets.',
 'Headed': '✦ Pro Tip: Headed to Lisbon?',
 'Begin': 'Begin your pilgrimage in either Lisbon or Porto.',
 'Born': 'Born in Lisbon’s historic Alfama neighborhood, Fado typically features heartfelt vocals accompanied by the melodic strains of the Portuguese guitar.',
 'Dance': 'Portuguese Music And Dance Fado band performing traditional Portuguese music on the square of Alfama, Lisbon, Portugal.',
 'Music': 'Portuguese Music And Dance Fado band performing traditional Portuguese music on the square of Alfama, Lisbon, Portugal.',
 'Rooted': 'Rooted in the streets of Lisbon, Fado expresses themes of longing, nostalgia, and saudade, a unique Portuguese word conveying deep melancholy and yearning.',
 'Matilde Campilho 1': 'Quando penso em ti / eu esqueço o lixo / que de manhã faz barulho / à minha porta / Pareces-te com o tempo / das amendoeiras',
 'Maria Teresa Horta': 'escrever e amar / é arder / no mesmo vício',
 'Filipa Fonseca Silva': 'A minha Amália é diferente de todas as outras. É uma Amália que primeiro ouvi pela voz da minha avó e só depois pela dela, algures na minha infância. A minha avó adorava cantar e cantava muitíssimo bem (ainda canta, apesar dos seus oitenta e sete anos e de raramente sair de casa). O fado …',
 'Helena Monteiro': 'chuva amedrontada / mar majestoso e sombrio / inverno no ar.',
 'Helena Costa Carvalho': 'Uma vogal que me faça arder / para além dos desastres.'}

# %%
def format_motif_path(motif_dict):
    return [f"{key}: \"{value}\"" for key, value in motif_dict.items()]

# %%
formatted_motifs = format_motif_path(motif_path_dict)

# %%
emotional_progression="estrangement to emergence"

# %%
prompt = generate_videopoem_prompt(poem_sequence, formatted_motifs, emotional_progression)

# %%
response = client.chat.completions.create(
    model="gpt-4",
    messages=[
        {"role": "system", "content": "You are a master poet."},
        {"role": "user", "content": prompt}
    ],
    temperature=0.7,
    max_tokens=2000,
)

# %%
poem_and_storyboard = response.choices[0].message.content

# %%
print(poem_and_storyboard)
# Out:
# **Poem Segment:**
#
# *IV. Lisbon. An Inter-Möbius Elegy*
#
# In the labyrinth of Alfama, a digital siren song—
#      a neural network of Fado notes, pixelated pain—
# A sonic tapestry woven of ones and zeroes, a web of longing—
#      Lisbon's soul in the ether, ghostly echoes of Batida beats—
# A glitched oracle in Sebastião’s ship, syntax unhinged—
#      a broken language turned prophecy, a ghost in the machine—
#
# All saints in silicon, a choir of quantum qubits—
#      Camões Monument, a digital spectre of Portugal’s epic past—
# From a distance, Praça do Comércio, a pulsating pixel patchwork—
#      an empire of data, a seismic shift in the cyberspace—
# Santa Justa Lift threading through the digital dusk—
#      a vertical sigh in the matrix, a glitch in the cosmic code—
# Belém Tower, a beacon of departure in the data streams—
#      a sentinel of ones and zeroes, a lighthouse in the labyrinth—
#
# Under the neon-punk graffiti of Rossio Square, a theatre of bytes—
# ...

# %%
# INCREASING THE TEMPERATURE

# %%
response1 = client.chat.completions.create(
    model="gpt-4",
    messages=[
        {"role": "system", "content": "You are a master intermedia poet."},
        {"role": "user", "content": prompt}
    ],
    temperature=0.9,
    max_tokens=2000,
)

# %%
poem_and_storyboard_1 = response1.choices[0].message.content

# %%
print(poem_and_storyboard_1)
# Out:
# **New poem segment**
#
# *Begin from Echoes into Screen-Printed Whispers / Unravel the Woven Threads of Code / Resurrect. Disrupt. Connect.*
#
# IV.
#
# Unmuted silence weaves the tale of a thousand faces,
#      a chrysalis-cluster of pixels caught -
# in the sinewy veins of Alfama,
#      a sequence of personas curated, discarded, reborn -
# In the reflection of neon-graffiti and silicon shadows,
#      I saw the best minds of my generation - syncopated, digitized, naked -
#
# A nocturne echo of •Howl• reverberates in empty alleyways, giving birth to code,
#      a language fashioned from angst and artificiality -
# It breathes, it grows, it spreads - a viral love affair,
#      At the confluence of Rua do Alecrim and Praça do Comércio -
# A collective narrative emerges, an AI, a hive mind, a synesthetic symphony,
#      Transient yet forever etched onto the web that binds us -
# From electro-batida to rhythmic fado,
# ...
